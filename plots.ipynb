# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('seaborn')

# %%
system_parameters = pd.read_csv(
    os.path.join(os.getcwd(), 'data', 'system_parameters.csv'),
    sep=';',
)
system_parameters
# Out:
#         temperature  pressure  kinetic_energy  potential_energy  total_energy
# 0          0.000030  0.000022        0.004202      -6781.907727  -6781.903525
# 1          0.000002  0.000002        0.004202      -6781.989170  -6781.984968
# 2          0.000099  0.000074        0.202888      -6782.054211  -6781.851323
# 3          0.000126  0.000094        0.259290      -6782.485006  -6782.225716
# 4          0.000152  0.000114        0.313624      -6782.582996  -6782.269372
# ...             ...       ...             ...               ...           ...
# 199995     2.874127  2.145121     5914.953011      -8238.221681  -2323.268670
# 199996     2.892023  2.158478     5951.784123      -8374.611654  -2422.827530
# 199997     2.866105  2.139133     5898.443251      -8448.186448  -2549.743197
# 199998     2.836515  2.117049     5837.546990      -8484.885688  -2647.338698
# 199999     2.818240  2.103409     5799.937574      -8501.836987  -2701.899413
#
# [200000 rows x 5 columns]

# %%
plt.scatter(
    system_parameters.index,
    system_parameters['temperature'],
    s=0.3,
);
plt.ylim(bottom=0, top=3);

# %%
plt.scatter(
    system_parameters.index,
    system_parameters['pressure'],
    s=1,
);
plt.ylim(bottom=0, top=3);

# %%
plt.scatter(
    system_parameters.index,
    system_parameters['kinetic_energy'],
    s=1,
);
plt.ylim(bottom=0, top=6000);

# %%
plt.scatter(
    system_parameters.index,
    system_parameters['potential_energy'],
    s=1,
);
plt.ylim(bottom=-10000, top=-5000);

# %%
plt.scatter(
    system_parameters.index,
    system_parameters['total_energy'],
    s=1,
);
plt.ylim(bottom=-10000, top=1000);
