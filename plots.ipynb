# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('seaborn')

# %%
system_parameters = pd.read_csv(
    os.path.join(
        os.getcwd(), 
        'data', 
        'success',
        'system_parameters.csv',
    ),
    sep=';',
)

for column in system_parameters.columns:
    system_parameters[column] = system_parameters[column].round(5)

system_parameters
# Out:
#        temperature  pressure  kinetic_energy  potential_energy  total_energy
# 0          0.00011  -5.87849         0.00000       -7985.84092   -7985.84092
# 1          0.00000  -5.87858         0.00000       -7985.84092   -7985.84092
# 2          0.00021  -5.87862         0.43218       -7986.16842   -7985.73624
# 3          0.00031  -5.87858         0.63778       -7986.32037   -7985.68259
# 4          0.00041  -5.87850         0.84303       -7986.28421   -7985.44119
# ...            ...       ...             ...               ...           ...
# 39995      2.80019   1.94823      5762.78197        -690.53187    5072.25011
# 39996      2.80102   1.94057      5764.50116        -693.66690    5070.83426
# 39997      2.80137   1.93203      5765.22911        -696.90236    5068.32675
# 39998      2.80162   1.92408      5765.72740        -700.00005    5065.72735
# 39999      2.80139   1.91763      5765.25826        -702.40590    5062.85236
#
# [40000 rows x 5 columns]

# %%
times = (system_parameters.index + 1) * 0.005

# %%
plt.scatter(
    times,
    system_parameters['temperature'],
    s=1,
);
plt.xlabel(r'Time, $\tau$', fontsize=16);
plt.ylabel(r'Temperature, $\epsilon / k_B$', fontsize=16);

# %%
plt.scatter(
    times,
    system_parameters['pressure'],
    s=1,
);
plt.xlabel(r'Time, $\tau$', fontsize=16);
plt.ylabel(r'Pressure, $\epsilon / \sigma^3 $', fontsize=16);

# %%
plt.scatter(
    times,
    system_parameters['kinetic_energy'],
    s=1,
);
plt.xlabel(r'Time, $\tau$', fontsize=16);
plt.ylabel(r'Kinetic Energy, $\epsilon$', fontsize=16);

# %%
plt.scatter(
    times,
    system_parameters['potential_energy'],
    s=1,
);
plt.xlabel(r'Time, $\tau$', fontsize=16);
plt.ylabel(r'Potential Energy, $\epsilon$', fontsize=16);

# %%
plt.scatter(
    times,
    system_parameters['total_energy'],
    s=1,
);
plt.xlabel(r'Time, $\tau$', fontsize=16);
plt.ylabel(r'Total Energy, $\epsilon$', fontsize=16);
